# %% [markdown]
# # 02 — Model Evaluation
#
# Evaluate HAI-DEF model performance on the validation / test set.
# **Requires model weights** — run `bash scripts/download_models.sh` first.
# **Never evaluate on real patient data** — use only de-identified or synthetic data.
#
# ## Contents
# 1. Model loading
# 2. Inference on validation set
# 3. Metrics: AUC-ROC, sensitivity, specificity, F1
# 4. Failure analysis — worst predictions
# 5. Confidence calibration

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve, classification_report
from pathlib import Path

from src.config.loader import load_config
cfg = load_config()
print('Config loaded')

# %% [markdown]
# ## 1. Model Loading

# %%
# TODO: Load model — pick one based on evaluation target
# from src.models.medgemma.inference import load_medgemma
# model, processor = load_medgemma(cfg['models']['medgemma'])

# from src.models.cxr_foundation.embeddings import load_cxr_foundation
# model = load_cxr_foundation(cfg['models']['cxr_foundation'])

# %% [markdown]
# ## 2. Inference on Validation Set

# %%
# TODO: Load validation set, run inference, collect predictions and labels
y_true = []  # ground truth labels
y_pred = []  # model predicted probabilities
y_pred_labels = []  # thresholded predictions

# %% [markdown]
# ## 3. Metrics

# %%
# TODO: Compute metrics after populating y_true / y_pred above
# auc = roc_auc_score(y_true, y_pred)
# print(f'AUC-ROC: {auc:.4f}')
# print(classification_report(y_true, y_pred_labels))

# %%
# TODO: Plot ROC curve
# fpr, tpr, _ = roc_curve(y_true, y_pred)
# plt.plot(fpr, tpr, label=f'AUC = {auc:.3f}')
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlabel('FPR'); plt.ylabel('TPR'); plt.title('ROC Curve')
# plt.legend(); plt.show()

# %% [markdown]
# ## 4. Failure Analysis

# %%
# TODO: Find worst predictions (highest confidence wrong predictions)
# and visualise them for qualitative error analysis

# %% [markdown]
# ## 5. Confidence Calibration

# %%
# TODO: Plot calibration curve (reliability diagram)
# from sklearn.calibration import calibration_curve
# prob_true, prob_pred = calibration_curve(y_true, y_pred, n_bins=10)
# plt.plot(prob_pred, prob_true, marker='o')
# plt.plot([0, 1], [0, 1], 'k--'); plt.title('Calibration'); plt.show()
