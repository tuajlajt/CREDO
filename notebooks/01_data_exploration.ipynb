# %% [markdown]
# # 01 — Data Exploration
#
# Explore the synthetic (and, where available, de-identified) dataset.
# **Never load real patient data (`data/raw/`) into this notebook.**
# Use only `data/synthetic/` or de-identified exports from `data/deidentified/`.
#
# ## Contents
# 1. Dataset overview
# 2. DICOM metadata inspection
# 3. Image quality checks
# 4. Class distribution
# 5. Preprocessing sanity checks

# %%
import sys
sys.path.insert(0, '..')  # project root

import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path('../data/synthetic')
print('Data directory:', DATA_DIR.resolve())
print('Files:', list(DATA_DIR.glob('*'))[:10])

# %% [markdown]
# ## 1. Dataset Overview

# %%
# TODO: Load dataset manifest / metadata CSV
# df = pd.read_csv(DATA_DIR / 'manifest.csv')
# df.head()

# %% [markdown]
# ## 2. DICOM Metadata Inspection

# %%
from src.data.dicom_loader import load_dicom_series, extract_safe_metadata

# TODO: Load a sample DICOM from data/synthetic/
# pixel_array, metadata = load_dicom_series(DATA_DIR / 'sample.dcm')
# print(metadata)

# %% [markdown]
# ## 3. Image Quality Checks

# %%
from src.preprocessing.qc import check_cxr_quality

# TODO: Run QC on sample images and visualise results

# %% [markdown]
# ## 4. Class Distribution

# %%
# TODO: Plot class distribution for classification tasks

# %% [markdown]
# ## 5. Preprocessing Sanity Checks

# %%
from src.preprocessing.cxr import preprocess_cxr

# TODO: Load, preprocess, and visualise a sample CXR
